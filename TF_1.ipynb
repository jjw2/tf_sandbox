# %%
from tensorflow.examples.tutorials.mnist import input_data
mnist = input_data.read_data_sets(".", one_hot=True, reshape=False)
# Out:
# Successfully downloaded train-images-idx3-ubyte.gz 9912422 bytes.
# Extracting ./train-images-idx3-ubyte.gz
# Successfully downloaded train-labels-idx1-ubyte.gz 28881 bytes.
# Extracting ./train-labels-idx1-ubyte.gz
# Successfully downloaded t10k-images-idx3-ubyte.gz 1648877 bytes.
# Extracting ./t10k-images-idx3-ubyte.gz
# Successfully downloaded t10k-labels-idx1-ubyte.gz 4542 bytes.
# Extracting ./t10k-labels-idx1-ubyte.gz

# %%
# Parameters

import tensorflow as tf

# Parameters
learning_rate = 0.00001
epochs = 10
batch_size = 128

# Number of samples to calculate validation and accuracy
# Decrease this if you're running out of memory to calculate accuracy
test_valid_size = 256

# Network Parameters
n_classes = 10  # MNIST total classes (0-9 digits)
dropout = 0.75  # Dropout, probability to keep units


# Store layers weight & bias
weights = {
    'wc1': tf.Variable(tf.random_normal([5, 5, 1, 32])),
    'wc2': tf.Variable(tf.random_normal([5, 5, 32, 64])),
    'wd1': tf.Variable(tf.random_normal([7*7*64, 1024])),
    'out': tf.Variable(tf.random_normal([1024, n_classes]))}

biases = {
    'bc1': tf.Variable(tf.random_normal([32])),
    'bc2': tf.Variable(tf.random_normal([64])),
    'bd1': tf.Variable(tf.random_normal([1024])),
    'out': tf.Variable(tf.random_normal([n_classes]))}

# %%
# Helper functions

def conv2d(x, W, b, strides=1):
    x = tf.nn.conv2d(x, W, strides=[1, strides, strides, 1], padding='SAME')
    x = tf.nn.bias_add(x, b)
    return tf.nn.relu(x)

def maxpool2d(x, k=2):
    return tf.nn.max_pool(
        x,
        ksize=[1, k, k, 1],
        strides=[1, k, k, 1],
        padding='SAME')

def conv_net(x, weights, biases, dropout):
    # Layer 1 - 28*28*1 to 14*14*32
    conv1 = conv2d(x, weights['wc1'], biases['bc1'])
    conv1 = maxpool2d(conv1, k=2)

    # Layer 2 - 14*14*32 to 7*7*64
    conv2 = conv2d(conv1, weights['wc2'], biases['bc2'])
    conv2 = maxpool2d(conv2, k=2)

    # Fully connected layer - 7*7*64 to 1024
    fc1 = tf.reshape(conv2, [-1, weights['wd1'].get_shape().as_list()[0]])
    fc1 = tf.add(tf.matmul(fc1, weights['wd1']), biases['bd1'])
    fc1 = tf.nn.relu(fc1)
    fc1 = tf.nn.dropout(fc1, dropout)

    # Output Layer - class prediction - 1024 to 10
    out = tf.add(tf.matmul(fc1, weights['out']), biases['out'])
    return out

# %%
# tf Graph input
x = tf.placeholder(tf.float32, [None, 28, 28, 1])
y = tf.placeholder(tf.float32, [None, n_classes])
keep_prob = tf.placeholder(tf.float32)

# Model
logits = conv_net(x, weights, biases, keep_prob)

# Define loss and optimizer
cost = tf.reduce_mean(\
    tf.nn.softmax_cross_entropy_with_logits(logits=logits, labels=y))
optimizer = tf.train.GradientDescentOptimizer(learning_rate=learning_rate)\
    .minimize(cost)

# Accuracy
correct_pred = tf.equal(tf.argmax(logits, 1), tf.argmax(y, 1))
accuracy = tf.reduce_mean(tf.cast(correct_pred, tf.float32))

# Initializing the variables
init = tf. global_variables_initializer()

# Launch the graph
with tf.Session() as sess:
    sess.run(init)

    for epoch in range(epochs):
        for batch in range(mnist.train.num_examples//batch_size):
            batch_x, batch_y = mnist.train.next_batch(batch_size)
            sess.run(optimizer, feed_dict={
                x: batch_x,
                y: batch_y,
                keep_prob: dropout})

            # Calculate batch loss and accuracy
            loss = sess.run(cost, feed_dict={
                x: batch_x,
                y: batch_y,
                keep_prob: 1.})
            valid_acc = sess.run(accuracy, feed_dict={
                x: mnist.validation.images[:test_valid_size],
                y: mnist.validation.labels[:test_valid_size],
                keep_prob: 1.})

            print('Epoch {:>2}, Batch {:>3} -'
                  'Loss: {:>10.4f} Validation Accuracy: {:.6f}'.format(
                epoch + 1,
                batch + 1,
                loss,
                valid_acc))

    # Calculate Test Accuracy
    test_acc = sess.run(accuracy, feed_dict={
        x: mnist.test.images[:test_valid_size],
        y: mnist.test.labels[:test_valid_size],
        keep_prob: 1.})
    print('Testing Accuracy: {}'.format(test_acc))
# Out:
# Epoch  1, Batch   1 -Loss: 67643.6172 Validation Accuracy: 0.121094
# Epoch  1, Batch   2 -Loss: 51046.3281 Validation Accuracy: 0.125000
# Epoch  1, Batch   3 -Loss: 43463.7852 Validation Accuracy: 0.156250
# Epoch  1, Batch   4 -Loss: 44954.7578 Validation Accuracy: 0.171875
# Epoch  1, Batch   5 -Loss: 35919.7578 Validation Accuracy: 0.179688
# Epoch  1, Batch   6 -Loss: 33780.8086 Validation Accuracy: 0.187500
# Epoch  1, Batch   7 -Loss: 29840.8066 Validation Accuracy: 0.191406
# Epoch  1, Batch   8 -Loss: 28423.6543 Validation Accuracy: 0.207031
# Epoch  1, Batch   9 -Loss: 28457.8008 Validation Accuracy: 0.199219
# Epoch  1, Batch  10 -Loss: 24370.4141 Validation Accuracy: 0.199219
# Epoch  1, Batch  11 -Loss: 22805.6367 Validation Accuracy: 0.207031
# Epoch  1, Batch  12 -Loss: 28339.7227 Validation Accuracy: 0.207031
# Epoch  1, Batch  13 -Loss: 20789.8320 Validation Accuracy: 0.246094
# Epoch  1, Batch  14 -Loss: 18860.4023 Validation Accuracy: 0.261719
# Epoch  1, Batch  15 -Loss: 20930.4043 Validation Accuracy: 0.281250
# Epoch  1, Batch  16 -Loss: 19966.7754 Validation Accuracy: 0.296875
# Epoch  1, Batch  17 -Loss: 19770.1934 Validation Accuracy: 0.320312
# Epoch  1, Batch  18 -Loss: 17536.9688 Validation Accuracy: 0.328125
# Epoch  1, Batch  19 -Loss: 18772.6367 Validation Accuracy: 0.304688
# Epoch  1, Batch  20 -Loss: 18628.6699 Validation Accuracy: 0.289062
# Epoch  1, Batch  21 -Loss: 17731.9238 Validation Accuracy: 0.316406
# Epoch  1, Batch  22 -Loss: 16076.2441 Validation Accuracy: 0.328125
# Epoch  1, Batch  23 -Loss: 16791.6230 Validation Accuracy: 0.328125
# Epoch  1, Batch  24 -Loss: 15604.3730 Validation Accuracy: 0.371094
# Epoch  1, Batch  25 -Loss: 14512.6230 Validation Accuracy: 0.367188
# Epoch  1, Batch  26 -Loss: 17907.4512 Validation Accuracy: 0.394531
# Epoch  1, Batch  27 -Loss: 15174.9463 Validation Accuracy: 0.398438
# Epoch  1, Batch  28 -Loss: 10332.6592 Validation Accuracy: 0.417969
# Epoch  1, Batch  29 -Loss: 17367.2734 Validation Accuracy: 0.429688
# Epoch  1, Batch  30 -Loss: 17219.8867 Validation Accuracy: 0.437500
# Epoch  1, Batch  31 -Loss: 16106.7910 Validation Accuracy: 0.441406
# Epoch  1, Batch  32 -Loss: 11306.2363 Validation Accuracy: 0.445312
# Epoch  1, Batch  33 -Loss: 12196.3154 Validation Accuracy: 0.441406
# Epoch  1, Batch  34 -Loss: 12031.4111 Validation Accuracy: 0.468750
# Epoch  1, Batch  35 -Loss: 12815.2607 Validation Accuracy: 0.480469
# Epoch  1, Batch  36 -Loss: 12748.9473 Validation Accuracy: 0.472656
# Epoch  1, Batch  37 -Loss:  9147.7988 Validation Accuracy: 0.464844
# Epoch  1, Batch  38 -Loss: 13448.5156 Validation Accuracy: 0.453125
# Epoch  1, Batch  39 -Loss: 11883.8340 Validation Accuracy: 0.453125
# Epoch  1, Batch  40 -Loss: 12980.6445 Validation Accuracy: 0.468750
# Epoch  1, Batch  41 -Loss: 12319.6963 Validation Accuracy: 0.488281
# Epoch  1, Batch  42 -Loss:  9632.8906 Validation Accuracy: 0.484375
# Epoch  1, Batch  43 -Loss:  8324.7070 Validation Accuracy: 0.480469
# Epoch  1, Batch  44 -Loss:  8600.8936 Validation Accuracy: 0.492188
# Epoch  1, Batch  45 -Loss:  9063.2471 Validation Accuracy: 0.500000
# Epoch  1, Batch  46 -Loss:  7724.5435 Validation Accuracy: 0.527344
# Epoch  1, Batch  47 -Loss:  7842.9219 Validation Accuracy: 0.515625
# Epoch  1, Batch  48 -Loss: 10779.4834 Validation Accuracy: 0.539062
# Epoch  1, Batch  49 -Loss:  8245.4199 Validation Accuracy: 0.535156
# Epoch  1, Batch  50 -Loss:  9863.3291 Validation Accuracy: 0.539062
# Epoch  1, Batch  51 -Loss:  8540.2949 Validation Accuracy: 0.542969
# Epoch  1, Batch  52 -Loss: 10865.7295 Validation Accuracy: 0.535156
# Epoch  1, Batch  53 -Loss:  8445.1729 Validation Accuracy: 0.554688
# Epoch  1, Batch  54 -Loss:  7992.4023 Validation Accuracy: 0.558594
# Epoch  1, Batch  55 -Loss:  9406.1973 Validation Accuracy: 0.554688
# Epoch  1, Batch  56 -Loss:  8662.7988 Validation Accuracy: 0.531250
# Epoch  1, Batch  57 -Loss:  9564.2607 Validation Accuracy: 0.542969
# Epoch  1, Batch  58 -Loss: 11161.6465 Validation Accuracy: 0.550781
# Epoch  1, Batch  59 -Loss:  6353.9736 Validation Accuracy: 0.574219
# Epoch  1, Batch  60 -Loss:  9327.0840 Validation Accuracy: 0.562500
# Epoch  1, Batch  61 -Loss:  7180.3652 Validation Accuracy: 0.574219
# Epoch  1, Batch  62 -Loss:  6888.8096 Validation Accuracy: 0.593750
# Epoch  1, Batch  63 -Loss:  8405.9922 Validation Accuracy: 0.582031
# Epoch  1, Batch  64 -Loss:  7913.6113 Validation Accuracy: 0.585938
# Epoch  1, Batch  65 -Loss:  6712.4775 Validation Accuracy: 0.574219
# Epoch  1, Batch  66 -Loss:  6399.0117 Validation Accuracy: 0.558594
# Epoch  1, Batch  67 -Loss:  4968.4116 Validation Accuracy: 0.574219
# Epoch  1, Batch  68 -Loss:  7658.4131 Validation Accuracy: 0.570312
# Epoch  1, Batch  69 -Loss:  9308.8877 Validation Accuracy: 0.566406
# Epoch  1, Batch  70 -Loss:  7851.1240 Validation Accuracy: 0.566406
# Epoch  1, Batch  71 -Loss:  7823.5239 Validation Accuracy: 0.558594
# Epoch  1, Batch  72 -Loss:  5887.1831 Validation Accuracy: 0.582031
# Epoch  1, Batch  73 -Loss:  7908.7261 Validation Accuracy: 0.585938
# Epoch  1, Batch  74 -Loss:  5857.1245 Validation Accuracy: 0.589844
# Epoch  1, Batch  75 -Loss:  6807.2065 Validation Accuracy: 0.585938
# Epoch  1, Batch  76 -Loss:  8132.5469 Validation Accuracy: 0.605469
# Epoch  1, Batch  77 -Loss:  8817.4102 Validation Accuracy: 0.585938
# Epoch  1, Batch  78 -Loss:  5013.5117 Validation Accuracy: 0.597656
# Epoch  1, Batch  79 -Loss:  6107.3579 Validation Accuracy: 0.593750
# Epoch  1, Batch  80 -Loss:  5520.8315 Validation Accuracy: 0.601562
# Epoch  1, Batch  81 -Loss:  5707.4424 Validation Accuracy: 0.605469
# Epoch  1, Batch  82 -Loss:  6697.2490 Validation Accuracy: 0.605469
# Epoch  1, Batch  83 -Loss:  5478.5376 Validation Accuracy: 0.593750
# Epoch  1, Batch  84 -Loss:  7056.5024 Validation Accuracy: 0.597656
# Epoch  1, Batch  85 -Loss:  6390.8145 Validation Accuracy: 0.589844
# Epoch  1, Batch  86 -Loss:  6871.2183 Validation Accuracy: 0.605469
# Epoch  1, Batch  87 -Loss:  6036.9116 Validation Accuracy: 0.601562
# Epoch  1, Batch  88 -Loss:  5958.0322 Validation Accuracy: 0.601562
# Epoch  1, Batch  89 -Loss:  4531.8135 Validation Accuracy: 0.605469
# Epoch  1, Batch  90 -Loss:  3669.6155 Validation Accuracy: 0.597656
# Epoch  1, Batch  91 -Loss:  5496.4941 Validation Accuracy: 0.609375
# Epoch  1, Batch  92 -Loss:  6714.2144 Validation Accuracy: 0.621094
# Epoch  1, Batch  93 -Loss:  6722.5938 Validation Accuracy: 0.605469
# Epoch  1, Batch  94 -Loss:  5810.9937 Validation Accuracy: 0.621094
# Epoch  1, Batch 173 -Loss:  3120.4277 Validation Accuracy: 0.687500
# Epoch  1, Batch 174 -Loss:  3781.0000 Validation Accuracy: 0.691406
# Epoch  1, Batch 175 -Loss:  3251.6985 Validation Accuracy: 0.683594
# Epoch  1, Batch 176 -Loss:  2815.4224 Validation Accuracy: 0.683594
# Epoch  1, Batch 177 -Loss:  3313.6191 Validation Accuracy: 0.679688
# Epoch  1, Batch 178 -Loss:  2731.4807 Validation Accuracy: 0.687500
# Epoch  1, Batch 179 -Loss:  2778.5605 Validation Accuracy: 0.687500
# Epoch  1, Batch 180 -Loss:  2196.1592 Validation Accuracy: 0.687500
# Epoch  1, Batch 181 -Loss:  2448.7419 Validation Accuracy: 0.687500
# Epoch  1, Batch 182 -Loss:  2628.9233 Validation Accuracy: 0.683594
# Epoch  1, Batch 183 -Loss:  4103.0049 Validation Accuracy: 0.683594
# Epoch  1, Batch 184 -Loss:  2057.3755 Validation Accuracy: 0.695312
# Epoch  1, Batch 185 -Loss:  3356.3555 Validation Accuracy: 0.695312
# Epoch  1, Batch 186 -Loss:  2432.8701 Validation Accuracy: 0.695312
# Epoch  1, Batch 187 -Loss:  2230.1282 Validation Accuracy: 0.695312
# Epoch  1, Batch 188 -Loss:  3576.5273 Validation Accuracy: 0.718750
# Epoch  1, Batch 189 -Loss:  3357.4670 Validation Accuracy: 0.710938
# Epoch  1, Batch 190 -Loss:  2138.3940 Validation Accuracy: 0.714844
# Epoch  1, Batch 191 -Loss:  2107.1663 Validation Accuracy: 0.714844
# Epoch  1, Batch 192 -Loss:  2761.1064 Validation Accuracy: 0.714844
# Epoch  1, Batch 193 -Loss:  2268.0952 Validation Accuracy: 0.710938
# Epoch  1, Batch 194 -Loss:  4295.8018 Validation Accuracy: 0.714844
# Epoch  1, Batch 195 -Loss:  3918.9980 Validation Accuracy: 0.710938
# Epoch  1, Batch 196 -Loss:  3089.1211 Validation Accuracy: 0.710938
# Epoch  1, Batch 197 -Loss:  3824.2632 Validation Accuracy: 0.722656
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-5-5ff0f3be3dc1> in <module>()
#      38                 x: mnist.validation.images[:test_valid_size],
#      39                 y: mnist.validation.labels[:test_valid_size],
# ---> 40                 keep_prob: 1.})
#      41
#      42             print('Epoch {:>2}, Batch {:>3} -'
#
# /Applications/anaconda3/envs/carnd-term1/lib/python3.5/site-packages/tensorflow/python/client/session.py in run(self, fetches, feed_dict, options, run_metadata)
#     764     try:
#     765       result = self._run(None, fetches, feed_dict, options_ptr,
# --> 766                          run_metadata_ptr)
#     767       if run_metadata:
#     768         proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# /Applications/anaconda3/envs/carnd-term1/lib/python3.5/site-packages/tensorflow/python/client/session.py in _run(self, handle, fetches, feed_dict, options, run_metadata)
#     949
#     950     # Create a fetch handler to take care of the structure of fetches.
# --> 951     fetch_handler = _FetchHandler(self._graph, fetches, feed_dict_string)
#     952
#     953     # Run request and get response.
#
# /Applications/anaconda3/envs/carnd-term1/lib/python3.5/site-packages/tensorflow/python/client/session.py in __init__(self, graph, fetches, feeds)
#     405     """
#     406     with graph.as_default():
# --> 407       self._fetch_mapper = _FetchMapper.for_fetch(fetches)
#     408     self._fetches = []
#     409     self._targets = []
#
# /Applications/anaconda3/envs/carnd-term1/lib/python3.5/site-packages/tensorflow/python/client/session.py in for_fetch(fetch)
#     236         if isinstance(fetch, tensor_type):
#     237           fetches, contraction_fn = fetch_fn(fetch)
# --> 238           return _ElementFetchMapper(fetches, contraction_fn)
#     239     # Did not find anything.
#     240     raise TypeError('Fetch argument %r has invalid type %r' %
#
# /Applications/anaconda3/envs/carnd-term1/lib/python3.5/site-packages/tensorflow/python/client/session.py in __init__(self, fetches, contraction_fn)
#     261       contraction_fn: Callable as returned by a fetch_fn.
#     262     """
# --> 263     self._unique_fetches = []
#     264     for fetch in fetches:
#     265       try:
#
# KeyboardInterrupt:
